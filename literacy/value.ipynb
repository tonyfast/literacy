# %% [markdown]
# # Value of a Notebook
#
# A notebook is source code and narrative. Both humans and machines read linearly.
#
# ---
#
# # <big>R</big>eadability 🤓
#
# One Machine
#
# # <big>R</big>eusability 👩‍💻      👨‍💻
#
# A Few Machines
#
# # <big>R</big>eproducibility [👩‍🚀](https://github.com/chrislgarry/Apollo-11)[👨‍🚀](http://vimeo.com/28199826)
#
# Many Machines

# %%
    # %reload_ext literacy.template
# Out:
#     %reload_ext literacy.template

# %%
# The notebook is data.

    from nbformat import reads
    from pandas import *
    from pathlib import Path
    
    df = concat({
        path: DataFrame(reads(path.read_text(), 4).cells)
        for path in Path('.').glob('*.ipynb')
    })
    df
# Out:
# # The notebook is data.
#
#     from nbformat import reads
#     from pandas import *
#     from pathlib import Path
#
#     df = concat({
#         path: DataFrame(reads(path.read_text(), 4).cells)
#         for path in Path('.').glob('*.ipynb')
#     })
#     df
#                      cell_type  execution_count             metadata  \
# Untitled.ipynb    0   markdown              NaN                   {}
#                   1       code              1.0                   {}
#                   2       code              2.0                   {}
#                   3       code              3.0  {'collapsed': True}
#                   4       code              4.0                   {}
#                   5       code              5.0                   {}
#                   6       code              6.0                   {}
#                   7       code              7.0                   {}
# interaction.ipynb 0   markdown              NaN                   {}
# ...

# %%
# Output Formats

# nbconvert

Jupyter renderers
# Out:
# # Output Formats
#
# # nbconvert
#
# Jupyter renderers

# %%
# Restart and Run All
# Out:
# # Restart and Run All

# %%
# Importing Notebook

## Using nbconvert

## Using run
# Out:
# # Importing Notebook
#
# ## Using nbconvert
#
# ## Using run
